# %% [markdown]
# ### Kaggle Api - (Download dataset to) - Python - (Data Cleaning and Preprocessing) - Python-Pandas - (Load Data into MYSQL) - MYSQL - Data Analysis Using SQL

# %%
#import libraries
#!pip install kaggle
import kaggle

# %%
#download datasets from kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0

# %%
#extract file for zip file
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
#read data from file
import pandas as pd
df = pd.read_csv('orders.csv')
df.head(11)
# Out:
#     Order Id  Order Date       Ship Mode    Segment        Country  \
# 0          1  2023-03-01    Second Class   Consumer  United States
# 1          2  2023-08-15    Second Class   Consumer  United States
# 2          3  2023-01-10    Second Class  Corporate  United States
# 3          4  2022-06-18  Standard Class   Consumer  United States
# 4          5  2022-07-13  Standard Class   Consumer  United States
# 5          6  2022-03-13   Not Available   Consumer  United States
# 6          7  2022-12-28  Standard Class   Consumer  United States
# 7          8  2022-01-25  Standard Class   Consumer  United States
# 8          9  2023-03-23   Not Available   Consumer  United States
# 9         10  2023-05-16  Standard Class   Consumer  United States
# 10        11  2023-03-31   Not Available   Consumer  United States
#
#                City       State  Postal Code Region         Category  \
# 0         Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#Handle null values
#df['Ship Mode'].unique()
df = pd.read_csv('orders.csv', na_values = ['Not Available', 'unknown'])
df.head(11)
# Out:
#     Order Id  Order Date       Ship Mode    Segment        Country  \
# 0          1  2023-03-01    Second Class   Consumer  United States
# 1          2  2023-08-15    Second Class   Consumer  United States
# 2          3  2023-01-10    Second Class  Corporate  United States
# 3          4  2022-06-18  Standard Class   Consumer  United States
# 4          5  2022-07-13  Standard Class   Consumer  United States
# 5          6  2022-03-13             NaN   Consumer  United States
# 6          7  2022-12-28  Standard Class   Consumer  United States
# 7          8  2022-01-25  Standard Class   Consumer  United States
# 8          9  2023-03-23             NaN   Consumer  United States
# 9         10  2023-05-16  Standard Class   Consumer  United States
# 10        11  2023-03-31             NaN   Consumer  United States
#
#                City       State  Postal Code Region         Category  \
# 0         Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#Rename columns name to ensures valid identifiers
#convert to lower case then replace space with '_'
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent'],
#       dtype='object')

# %%
#checks datatype of the columns and covert order_date datatype into datetime
df.dtypes
pd.to_datetime(df['order_date'], format = '%Y-%m-%d')
# Out:
# 0      2023-03-01
# 1      2023-08-15
# 2      2023-01-10
# 3      2022-06-18
# 4      2022-07-13
#           ...
# 9989   2023-02-18
# 9990   2023-03-17
# 9991   2022-08-07
# 9992   2022-11-19
# 9993   2022-07-17
# Name: order_date, Length: 9994, dtype: datetime64[ns]

# %%
#Derive new columns sale_price, discount, profit
#df['discount'] = df['list_price']*df['discount_percent']*.01
#df['sale_price'] = df['list_price']-df['discount']
#df['profit'] = df['sale_price']-df['cost_price']
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#Drop cost_price, list_price and discount_percent columns
#df.drop(columns=['cost_price','list_price','discount_percent'], inplace = True)
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
#Connect mysql from python
#!pip install mysql-connector-python
#!pip install sqlalchemy

import sqlalchemy as sal
from sqlalchemy import create_engine

# Connect to the database
engine = create_engine("mysql+mysqlconnector://root:MyNewPass@localhost/project")

# Test the connection
connection = engine.connect()

# %%
#Load data into mysql using replace option

#Replace option by default create large datatype of value which occuipied space.
#df.to_sql('df_orders', con = connection, index = False, if_exists = 'replace')

# %%
#Load data into mysql using append option

#Firstly create empty table manually into mysql according to desired datatype.

df.to_sql('df_orders', con = connection, index = False, if_exists = 'append')
# Out:
# 9994

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sale_price', 'profit'],
#       dtype='object')
